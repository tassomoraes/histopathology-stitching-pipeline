# %% [markdown]
# ### Testando `re`

# %%
import re

COORD_PATTERN = re.compile(r"_x(\d+)_y(\d+)")

match = COORD_PATTERN.search("image_x123_y456.png")

print(match.group(1))  # Output: 123
# Out:
# Falha ao iniciar o Kernel.
#
# O kernel foi encerrado. Erro: ... Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
